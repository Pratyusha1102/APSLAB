# %% [markdown]
# <a href="https://colab.research.google.com/github/Pratyusha1102/APSLAB/blob/main/Lab_5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ### Write code for above cell and compute the running time and also plot graph. (Selection Sort)

# %%
def selection_sort(numbers):
    n = len(numbers)
    for i in range(n):
        min_idx = i
        for j in range(i + 1, n):
            if numbers[j] < numbers[min_idx]:
                min_idx = j
        numbers[i], numbers[min_idx] = numbers[min_idx], numbers[i]
    return numbers

#num_elements = int(input("Enter the number of elements: "))
#numbers_list = []
#print("Enter the elements:")
#for _ in range(num_elements):
#    element = int(input())
#    numbers_list.append(element)
#print("Original list:", numbers_list)
#sorted_list = selection_sort(numbers_list)
#print("Sorted list:", sorted_list)

# %%
import time
import random

def generate_random_list(size):
    return [random.randint(0, 1000) for _ in range(size)]

input_sizes = []
running_times = []

sizes_to_test = range(10, 51, 10)

for size in sizes_to_test:
    numbers_to_sort = generate_random_list(size)

    start_time = time.time()
    selection_sort(numbers_to_sort)
    end_time = time.time()

    elapsed_time = end_time - start_time

    input_sizes.append(size)
    running_times.append(elapsed_time)

print("Finished measuring running times.")
# Out:
# Finished measuring running times.

# %%
plt.figure()
plt.plot(input_sizes, running_times, marker='o', linestyle='-', label='Selection Sort')
plt.title('Selection Sort Running Time vs. Input Size')
plt.xlabel('Input Size (Number of Elements)')
plt.ylabel('Running Time (seconds)')
plt.legend()
plt.grid(True)
plt.show()
print("Graph plotted showing running time vs. input size.")
# Out:
# Graph plotted showing running time vs. input size.

# %% [markdown]
# ### Write code for above cell and compute the running time and also plot graph. (Merge Sort)

# %%
def merge_sort(numbers):
    if len(numbers) <= 1:
        return numbers

    mid = len(numbers) // 2
    left_half = numbers[:mid]
    right_half = numbers[mid:]

    left_half = merge_sort(left_half)
    right_half = merge_sort(right_half)

    return merge(left_half, right_half)

def merge(left, right):
    result = []
    i = 0
    j = 0

    while i < len(left) and j < len(right):
        if left[i] < right[j]:
            result.append(left[i])
            i += 1
        else:
            result.append(right[j])
            j += 1

    result.extend(left[i:])
    result.extend(right[j:])
    return result

# Example usage for verification
# numbers_list = [38, 27, 43, 3, 9, 82, 10]
# sorted_list = merge_sort(numbers_list)
# print("Original list:", numbers_list)
# print("Sorted list:", sorted_list)

print("Merge Sort functions defined.")
# Out:
# Merge Sort functions defined.

# %%
import time
import random

merge_sort_input_sizes = []
merge_sort_running_times = []

for size in sizes_to_test:
    numbers_to_sort_merge = generate_random_list(size)

    start_time_merge = time.time()
    merge_sort(numbers_to_sort_merge)
    end_time_merge = time.time()

    elapsed_time_merge = end_time_merge - start_time_merge

    merge_sort_input_sizes.append(size)
    merge_sort_running_times.append(elapsed_time_merge)

print("Finished measuring running times for Merge Sort.")
# Out:
# Finished measuring running times for Merge Sort.

# %%
plt.figure()
plt.plot(merge_sort_input_sizes, merge_sort_running_times, color='orange', marker='x', linestyle='--', label='Merge Sort')
#plt.plot(input_sizes, running_times, marker='x', linestyle='--', label='Selection Sort')
plt.title('Merge Sort Running Time vs. Input Size')
plt.xlabel('Input Size (Number of Elements)')
plt.ylabel('Running Time (seconds)')
plt.legend()
plt.grid(True)
plt.show()
print("Graph plotted showing running time vs. input size.")
# Out:
# Graph plotted showing running time vs. input size.

# %% [markdown]
# ### Write code for above cell and compute the running time and also plot graph. (Quick Sort)

# %%
def quick_sort(numbers):
    def _quick_sort_recursive(arr, low, high):
        if low < high:
            pi = partition(arr, low, high)
            _quick_sort_recursive(arr, low, pi - 1)
            _quick_sort_recursive(arr, pi + 1, high)

    def partition(arr, low, high):
        pivot = arr[high]  # Choosing the last element as the pivot
        i = low - 1
        for j in range(low, high):
            if arr[j] <= pivot:
                i += 1
                arr[i], arr[j] = arr[j], arr[i]
        arr[i + 1], arr[high] = arr[high], arr[i + 1]
        return i + 1

    # Make a copy to avoid modifying the original list if it's passed by reference and its sorted state is not desired outside
    arr_copy = list(numbers)
    _quick_sort_recursive(arr_copy, 0, len(arr_copy) - 1)
    return arr_copy

# Example usage for verification
# numbers_list = [10, 7, 8, 9, 1, 5]
# sorted_list = quick_sort(numbers_list)
# print("Original list:", numbers_list)
# print("Sorted list:", sorted_list)

print("Quick Sort function defined.")
# Out:
# Quick Sort function defined.

# %%
quick_sort_input_sizes = []
quick_sort_running_times = []

for size in sizes_to_test:
    numbers_to_sort_quick = generate_random_list(size)

    start_time_quick = time.time()
    quick_sort(numbers_to_sort_quick)
    end_time_quick = time.time()

    elapsed_time_quick = end_time_quick - start_time_quick

    quick_sort_input_sizes.append(size)
    quick_sort_running_times.append(elapsed_time_quick)

print("Finished measuring running times for Quick Sort.")
# Out:
# Finished measuring running times for Quick Sort.

# %%
plt.figure()
#plt.plot(input_sizes, running_times, marker='o', linestyle='-', label='Selection Sort', color='blue')
#plt.plot(merge_sort_input_sizes, merge_sort_running_times, marker='x', linestyle='--', label='Merge Sort', color='orange')
plt.plot(quick_sort_input_sizes, quick_sort_running_times, marker='s', linestyle='-.', label='Quick Sort', color='green')
plt.title('Quick Sort Running Time vs. Input Size')
plt.xlabel('Input Size (Number of Elements)')
plt.ylabel('Running Time (seconds)')
plt.legend()
plt.grid(True)
plt.show()
print("Graph plotted showing running time vs. input size.")
# Out:
# Graph plotted showing running time vs. input size.

# %% [markdown]
# ### Experiment: compare sorting algorithms

# %%
from datetime import datetime # Import datetime
import random

# Creating a random value (uniform)
ms = datetime.now().microsecond / 1000
random.seed(ms)

numbers = []
for i in range(n_max):
    numbers.append(int(random.random() * 1000))

# %%
# Plotting results
plt.figure(figsize=(10, 5))
plt.plot(input_sizes, running_times, marker='o', linestyle='-', label='Selection Sort', color='blue')
plt.plot(merge_sort_input_sizes, merge_sort_running_times, marker='x', linestyle='--', label='Merge Sort', color='orange')
plt.plot(quick_sort_input_sizes, quick_sort_running_times, marker='s', linestyle='-.', label='Quick Sort', color='green')
plt.title('Compare Sorting Algorithms')
plt.xlabel('Input Size (Number of Elements)')
plt.ylabel('Running Time (seconds)')
plt.legend()
plt.grid(True)
plt.show()
print("Graph plotted showing running time vs. input size.")
# Out:
# Graph plotted showing running time vs. input size.
