# %% [markdown]
# <a href="https://colab.research.google.com/github/Pratyusha1102/APSLAB/blob/main/Lab_9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Shortest Path Using Dijkstra Algorithm in Python
# Problem Description:
# Given a weighted graph with non negative edge weights. Find the shortest distance from a source vertex to all other vertices using Dijkstra algorithm

# %% [markdown]
# #Theory
# Dijkstra algorithm finds shortest distance from one source node to all other nodes in a weighted graph with non negative weights. Dictionary structure stores nodes as keys and neighbor nodes with weights as values.
#
# ##Algorithm Steps
#
# 1. Represent graph using dictionary.
# 2. Set distance of every node as infinity.
# 3. Set distance of source node as 0.
# 4. Select node with smallest distance among unvisited nodes.
# 5. Update distance of neighbor nodes.
# 6. Repeat until all nodes get visited.

# %%
def dijkstra(graph, start):
    distances = {}
    visited = []
    parent = {}

    for node in graph:
        distances[node] = float('inf')
        parent[node] = None

    distances[start] = 0

    while len(visited) < len(graph):

        min_node = None
        min_distance = float('inf')

        for node in graph:
            if node not in visited and distances[node] < min_distance:
                min_distance = distances[node]
                min_node = node

        if min_node is None:
            break

        visited.append(min_node)

        for neighbor, weight in graph[min_node].items():
            new_distance = distances[min_node] + weight

            if new_distance < distances[neighbor]:
                distances[neighbor] = new_distance
                parent[neighbor] = min_node

    return distances, parent

# %%
graph = {
'A': {'B': 4, 'C': 2, 'E': 7},
'B': {'A': 4, 'C': 5, 'D': 10, 'F': 3},
'C': {'A': 2, 'B': 5, 'D': 3},
'D': {'B': 10, 'C': 3, 'E': 2},
'E': {'A': 7, 'D': 2, 'F': 1},
'F': {'B': 3, 'E': 1}
}

result,parent = dijkstra(graph, 'A')

for node in result:
    print("Distance from A to", node, "=", result[node])
# Out:
# Distance from A to A = 0
# Distance from A to B = 4
# Distance from A to C = 2
# Distance from A to D = 5
# Distance from A to E = 7
# Distance from A to F = 7

# %%
sources = list(graph.keys())
for start in sources:
    print("\nSource Node:", start)
    distances, parent = dijkstra(graph, start)

    for node in graph:
        path = print_path(parent, start, node)
        print(f"{start} -> {node} = {distances[node]}, Path: {path}")
# Out:
# Source Node: A
# A -> A = 0, Path: ['A']
# A -> B = 4, Path: ['A', 'B']
# A -> C = 2, Path: ['A', 'C']
# A -> D = 5, Path: ['A', 'C', 'D']
# A -> E = 7, Path: ['A', 'E']
# A -> F = 7, Path: ['A', 'B', 'F']
#
# Source Node: B
# B -> A = 4, Path: ['B', 'A']
# B -> B = 0, Path: ['B']
# B -> C = 5, Path: ['B', 'C']
# B -> D = 6, Path: ['B', 'F', 'E', 'D']
# B -> E = 4, Path: ['B', 'F', 'E']
# B -> F = 3, Path: ['B', 'F']
#
# Source Node: C
# C -> A = 2, Path: ['C', 'A']
# C -> B = 5, Path: ['C', 'B']
# C -> C = 0, Path: ['C']
# C -> D = 3, Path: ['C', 'D']
# C -> E = 5, Path: ['C', 'D', 'E']
# C -> F = 6, Path: ['C', 'D', 'E', 'F']
#
# Source Node: D
# D -> A = 5, Path: ['D', 'C', 'A']
# D -> B = 6, Path: ['D', 'E', 'F', 'B']
# D -> C = 3, Path: ['D', 'C']
# D -> D = 0, Path: ['D']
# D -> E = 2, Path: ['D', 'E']
# D -> F = 3, Path: ['D', 'E', 'F']
#
# Source Node: E
# E -> A = 7, Path: ['E', 'A']
# E -> B = 4, Path: ['E', 'F', 'B']
# E -> C = 5, Path: ['E', 'D', 'C']
# E -> D = 2, Path: ['E', 'D']
# E -> E = 0, Path: ['E']
# E -> F = 1, Path: ['E', 'F']
#
# Source Node: F
# F -> A = 7, Path: ['F', 'B', 'A']
# F -> B = 3, Path: ['F', 'B']
# F -> C = 6, Path: ['F', 'E', 'D', 'C']
# F -> D = 3, Path: ['F', 'E', 'D']
# F -> E = 1, Path: ['F', 'E']
# F -> F = 0, Path: ['F']

# %% [markdown]
# Now, let's implement
# 1. Modify program for user input graph using dictionary.
# 2. Display shortest path with total distance.
# 3. Add two more nodes in graph.
# 4. Test algorithm with different source nodes.

# %%
def print_path(parent, start, node):
    path = []
    while node is not None:
        path.append(node)
        node = parent[node]
    path.reverse()
    return path

# %%
graph = {}

n = int(input("Enter number of nodes: "))

for _ in range(n):
    node = input("Enter node name: ")
    graph[node] = {}

    edges = int(input(f"Enter number of neighbors for {node}: "))
    for _ in range(edges):
        neighbor = input("Enter neighbor: ")
        weight = int(input("Enter weight: "))
        graph[node][neighbor] = weight
# Out:
# Enter number of nodes: 4
# Enter node name: A
# Enter number of neighbors for A: 2
# Enter neighbor: B
# Enter weight: 4
# Enter neighbor: C
# Enter weight: 2
# Enter node name: B
# Enter number of neighbors for B: 3
# Enter neighbor: A
# Enter weight: 4
# Enter neighbor: C
# Enter weight: 5
# Enter neighbor: D
# Enter weight: 10
# Enter node name: C
# Enter number of neighbors for C: 3
# Enter neighbor: A
# Enter weight: 2
# Enter neighbor: B
# Enter weight: 5
# Enter neighbor: D
# Enter weight: 3
# Enter node name: D
# Enter number of neighbors for D: 2
# Enter neighbor: B
# Enter weight: 10
# Enter neighbor: C
# Enter weight: 3
